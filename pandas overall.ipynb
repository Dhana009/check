# %%
import pandas as pd

# %%
nifty=pd.read_csv(r'C:\Users\HP\Downloads\niftydata.csv',names=['Trade_Date','Closing_Date'],nrows=30)

# %%
nifty
# Out:
#     Trade_Date  Closing_Date
# 0    9/17/2007   4494.649902
# 1    9/18/2007   4546.200195
# 2    9/19/2007   4732.350098
# 3    9/20/2007   4747.549805
# 4    9/21/2007   4837.549805
# 5    9/24/2007   4932.200195
# 6    9/25/2007   4938.850098
# 7    9/26/2007   4940.500000
# 8    9/27/2007   5000.549805
# 9    9/28/2007   5021.350098
# 10   10/1/2007   5068.950195
# 11   10/3/2007   5210.799805
# 12   10/4/2007   5208.649902
# 13   10/5/2007   5185.850098
# 14   10/8/2007   5085.100098
# 15   10/9/2007   5327.250000
# 16  10/10/2007   5441.450195
# 17  10/11/2007   5524.850098
# 18  10/12/2007   5428.250000
# 19  10/15/2007   5670.399902
# 20  10/16/2007   5668.049805
# 21  10/17/2007   5559.299805
# 22  10/18/2007   5351.000000
# 23  10/19/2007   5215.299805
# 24  10/22/2007   5184.000000
# 25  10/23/2007   5473.700195
# 26  10/24/2007   5496.149902
# 27  10/25/2007   5568.950195
# 28  10/26/2007   5702.299805
# 29  10/29/2007   5905.899902

# %%
loc=r'C:\Users\HP\Downloads\NewOrders.xlsx'
orders=pd.read_excel(loc)

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
orders.describe().T
# Out:
#                       count          mean           std         min  \
# Row ID               8399.0   4200.000000   2424.726789      1.0000
# Order ID             8399.0  29965.179783  17260.883447      3.0000
# Order Quantity       8399.0     25.571735     14.481071      1.0000
# Sales                8399.0   1775.878179   3585.050525      2.2400
# Discount             8399.0      0.049671      0.031823      0.0000
# Profit               8399.0    181.184422   1196.653326 -14140.7016
# Unit Price           8399.0     89.346259    290.354383      0.9900
# Shipping Cost        8399.0     12.838557     17.264052      0.4900
# Product Base Margin  8336.0      0.512513      0.135589      0.3500
#
#                            25%       50%        75%       max
# Row ID                2100.500   4200.00   6299.500   8399.00
# Order ID             15011.500  29857.00  44596.000  59973.00
# Order Quantity          13.000     26.00     38.000     50.00
# ...

# %%
orders.describe(include='all')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8784\3440501736.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders.describe(include='all')
# C:\Users\HP\AppData\Local\Temp\ipykernel_8784\3440501736.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders.describe(include='all')
#              Row ID      Order ID           Order Date Order Priority  \
# count   8399.000000   8399.000000                 8399           8399
# unique          NaN           NaN                 1418              5
# top             NaN           NaN  2011-09-15 00:00:00           High
# ...

# %%
orders.describe(include=['object','float']).T
# Out:
#                        count unique  \
# Order Priority          8399      5
# Sales                 8399.0    NaN
# Discount              8399.0    NaN
# Ship Mode               8399      3
# Profit                8399.0    NaN
# Unit Price            8399.0    NaN
# Shipping Cost         8399.0    NaN
# Customer Name           8399    795
# Province                8399     13
# Region                  8399      8
# Customer Segment        8399      4
# Product Category        8399      3
# Product Sub-Category    8399     17
# Product Name            8399   1263
# Product Container       8399      7
# Product Base Margin   8336.0    NaN
#
#                                                             top  freq  \
# Order Priority                                             High  1768
# Sales                                                       NaN   NaN
# Discount                                                    NaN   NaN
# ...

# %%
orders.describe(include=['object']).T
# Out:
#                      count unique                                        top  \
# Order Priority        8399      5                                       High
# Ship Mode             8399      3                                Regular Air
# Customer Name         8399    795                                Darren Budd
# Province              8399     13                                    Ontario
# Region                8399      8                                       West
# Customer Segment      8399      4                                  Corporate
# Product Category      8399      3                            Office Supplies
# Product Sub-Category  8399     17                                      Paper
# Product Name          8399   1263  Global High-Back Leather Tilter, Burgundy
# Product Container     8399      7                                  Small Box
#
#                       freq
# Order Priority        1768
# Ship Mode             6270
# Customer Name           41
# ...

# %%
orders[orders['Order Priority']=='High'].describe().T
# Out:
#                       count          mean           std       min         25%  \
# Row ID               1768.0   4280.267534   2453.694215      3.00   2190.5000
# Order ID             1768.0  30541.058824  17472.590404     32.00  15780.2500
# Order Quantity       1768.0     25.834276     14.544867      1.00     13.0000
# Sales                1768.0   1848.052240   3550.533040      3.41    157.8650
# Discount             1768.0      0.049446      0.031761      0.00      0.0200
# Profit               1768.0    230.243022   1293.987581 -11861.46    -83.2925
# Unit Price           1768.0     88.736985    239.446384      1.26      6.6800
# Shipping Cost        1768.0     12.819808     16.898160      0.49      3.0000
# Product Base Margin  1755.0      0.513350      0.133185      0.35      0.3800
#
#                           50%           75%       max
# Row ID                4283.50   6469.250000   8394.00
# Order ID             30515.50  46050.000000  59969.00
# ...

# %%
loc
# Out:
# 'C:\\Users\\HP\\Downloads\\NewOrders.xlsx'

# %%
orders.Sales.sort_values(ascending=False).head(8)
# Out:
# 4189    89061.05
# 451     45923.76
# 4263    41343.21
# 2025    33367.85
# 4628    29884.60
# 5234    29345.27
# 4872    29186.49
# 6851    28761.52
# Name: Sales, dtype: float64

# %%
orders['Order Date'].sort_values().head()
# Out:
# 1913   2009-01-01
# 4030   2009-01-01
# 5271   2009-01-02
# 6223   2009-01-02
# 6224   2009-01-02
# Name: Order Date, dtype: datetime64[ns]

# %%
orders.sort_values(['Sales','Discount'],ascending=False).head()
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 4189    4190     29766 2009-03-21         Medium              13  89061.05
# 451      452      3073 2009-01-07         Medium               7  45923.76
# 4263    4264     30343 2012-05-21       Critical               8  41343.21
# 2025    2026     14435 2012-12-01  Not Specified               9  33367.85
# 4628    4629     32932 2010-01-09            Low              49  29884.60
#
#       Discount    Ship Mode    Profit  Unit Price  ...    Customer Name  \
# 4189      0.00  Regular Air  27220.69     6783.02  ...       Emily Phan
# 451       0.07  Regular Air    102.61     6783.02  ...  Jasper Cacioppo
# 4263      0.09  Regular Air   3852.19     6783.02  ...   Craig Carreira
# 2025      0.01  Regular Air   3992.52     3499.99  ...      Dennis Kane
# 4628      0.05  Regular Air  12748.86      599.99  ...   Karen Carlisle
#
#               Province    Region Customer Segment Product Category  \
# ...

# %%
sales=pd.read_excel(r'C:\Users\HP\Downloads\Superstore Sales.xls')

# %%
sales.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
sales[sales.Sales>=500].head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 7       8        35 2011-10-22  Not Specified              14  1892.8480
# 8       9        36 2011-11-02       Critical              46  2484.7455
# 9      10        65 2011-03-17       Critical              32  3812.7300
#
#    Discount       Ship Mode    Profit  Unit Price  ...     Customer Name  \
# 2      0.07     Regular Air  1054.820      107.53  ...     Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...     Liz Pelletier
# 7      0.01     Regular Air    48.987      155.99  ...   Julie Creighton
# 8      0.10     Regular Air   657.477       65.99  ...  Sample Company A
# 9      0.02     Regular Air  1470.300      115.79  ...     Tamara Dahlen
#
#            Province   Region Customer Segment Product Category  \
# ...

# %%
sales[sales['Order Priority']!='High'].head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 6       7        35 2011-10-22  Not Specified              30   288.5600
# 7       8        35 2011-10-22  Not Specified              14  1892.8480
# 8       9        36 2011-11-02       Critical              46  2484.7455
#
#    Discount    Ship Mode   Profit  Unit Price  ...       Customer Name  \
# 0      0.04  Regular Air -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01  Regular Air   -4.640        2.08  ...         Ruben Dartt
# 6      0.03  Regular Air   60.720        9.11  ...     Julie Creighton
# 7      0.01  Regular Air   48.987      155.99  ...     Julie Creighton
# 8      0.10  Regular Air  657.477       65.99  ...    Sample Company A
#
#            Province   Region Customer Segment Product Category  \
# ...

# %%
sales[(sales['Order Priority']!='High')&(sales['Order Priority']!='Low')].head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 6       7        35 2011-10-22  Not Specified              30   288.5600
# 7       8        35 2011-10-22  Not Specified              14  1892.8480
# 8       9        36 2011-11-02       Critical              46  2484.7455
# 9      10        65 2011-03-17       Critical              32  3812.7300
#
#    Discount    Ship Mode    Profit  Unit Price  ...     Customer Name  \
# 1      0.01  Regular Air    -4.640        2.08  ...       Ruben Dartt
# 6      0.03  Regular Air    60.720        9.11  ...   Julie Creighton
# 7      0.01  Regular Air    48.987      155.99  ...   Julie Creighton
# 8      0.10  Regular Air   657.477       65.99  ...  Sample Company A
# 9      0.02  Regular Air  1470.300      115.79  ...     Tamara Dahlen
#
#            Province   Region Customer Segment Product Category  \
# ...

# %%
sales[sales['Ship Mode'].isin(['Regular Air','Delivery Truck'])]
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0          1         3 2010-10-13            Low               6   261.5400
# 1          2         6 2012-02-20  Not Specified               2     6.9300
# 2          3        32 2011-07-15           High              26  2808.0800
# 3          4        32 2011-07-15           High              24  1761.4000
# 4          5        32 2011-07-15           High              23   160.2335
# ...      ...       ...        ...            ...             ...        ...
# 8384    8385     59906 2010-05-20           High              32   284.9200
# 8385    8386     59909 2012-08-05            Low              11  1255.4800
# 8387    8388     59911 2011-12-18  Not Specified               1    10.5900
# 8388    8389     59937 2009-12-28           High               7   235.9800
# 8389    8390     59939 2010-09-01         Medium              42   130.9600
#
# ...

# %%
sales.drop('Order Date',axis='columns',inplace=True)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8390 entries, 0 to 8389
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8390 non-null   int64
#  1   Order ID              8390 non-null   int64
#  2   Order Priority        8390 non-null   object
#  3   Order Quantity        8390 non-null   int64
#  4   Sales                 8390 non-null   float64
#  5   Discount              8390 non-null   float64
#  6   Ship Mode             8390 non-null   object
#  7   Profit                8390 non-null   float64
#  8   Unit Price            8390 non-null   float64
#  9   Shipping Cost         8390 non-null   float64
#  10  Customer Name         8390 non-null   object
#  11  Province              8390 non-null   object
#  12  Region                8390 non-null   object
#  13  Customer Segment      8390 non-null   object
#  14  Product Category      8390 non-null   object
# ...

# %%
sales.drop([2,4],axis='rows',inplace=True)

# %%
sales.head()
# Out:
#    Row ID  Order ID Order Priority  Order Quantity    Sales  Discount  \
# 0       1         3            Low               6   261.54      0.04
# 1       2         6  Not Specified               2     6.93      0.01
# 3       4        32           High              24  1761.40      0.09
# 5       6        32           High              15   140.56      0.04
# 6       7        35  Not Specified              30   288.56      0.03
#
#         Ship Mode   Profit  Unit Price  Shipping Cost       Customer Name  \
# 0     Regular Air  -213.25       38.94          35.00  Muhammed MacIntyre
# 1     Regular Air    -4.64        2.08           2.56         Ruben Dartt
# 3  Delivery Truck -1748.56       70.89          89.30       Liz Pelletier
# 5     Regular Air  -128.38        8.46           8.99       Liz Pelletier
# 6     Regular Air    60.72        9.11           2.25     Julie Creighton
#
#            Province   Region Customer Segment Product Category  \
# ...

# %%
import json
json_data="""
{ "country":"india",
   "products":["wheat","gold","rice"],
   "contact":"null"}"""

# %%
comp_data=json.loads(json_data)

# %%
comp_data
# Out:
# {'country': 'india', 'products': ['wheat', 'gold', 'rice'], 'contact': 'null'}

# %%
print(comp_data['country'])
# Out:
# india

# %%
json_df=pd.DataFrame(comp_data)

# %%
json_df
# Out:
#   country products contact
# 0   india    wheat    null
# 1   india     gold    null
# 2   india     rice    null

# %%
del json_df['country']
json_df
# Out:
#   products contact
# 0    wheat    null
# 1     gold    null
# 2     rice    null

# %%
from pandas import Series

# %%
ser=Series([35,3,353,322])

# %%
ser
# Out:
# 0     35
# 1      3
# 2    353
# 3    322
# dtype: int64

# %%
ser.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
ser[0]
# Out:
# 35

# %%
ser=Series([35,3,353,322],index=['a','b','c','d'])

# %%
ser
# Out:
# a     35
# b      3
# c    353
# d    322
# dtype: int64

# %%
orders['Order Priority']+' '+orders['Ship Mode']
# Out:
# 0                 Low Regular Air
# 1       Not Specified Regular Air
# 2                High Regular Air
# 3             High Delivery Truck
# 4                High Regular Air
#                   ...
# 8394         Critical Express Air
# 8395         Critical Regular Air
# 8396         Critical Express Air
# 8397           Low Delivery Truck
# 8398           Low Delivery Truck
# Length: 8399, dtype: object

# %%
orders.Sales.size
# Out:
# 8399

# %%
url=r"https://pbpython.com/pandas-html-table.html"

# %%
tables_list=pd.io.html.read_html(url)

# %%
tables_list
# Out:
# [   Unnamed: 0  Year     Office    GOP    DFL Others
#  0           0  2018   Governor  42.4%  53.9%   3.7%
#  1           1  2018    Senator  36.2%  60.3%   3.4%
#  2           2  2018    Senator  42.4%  53.0%   4.6%
#  3           3  2016  President  44.9%  46.4%   8.6%
#  4           4  2014   Governor  44.5%  50.1%   5.4%,
#     Unnamed: 0  Year     Office   GOP   DFL  Others
#  0           0  2018   Governor  42.4  53.9     3.7
#  1           1  2018    Senator  36.2  60.3     3.4
#  2           2  2018    Senator  42.4  53.0     4.6
#  3           3  2016  President  44.9  46.4     8.6
#  4           4  2014   Governor  44.5  50.1     5.4,
#     Unnamed: 0  Year  Nominal GDP(in bil. US-Dollar)  \
#  0           0  2020                         20234.0
#  1           1  2019                         21439.0
#  2           2  2018                         20580.2
#  3           3  2017                         19519.4
#  4           4  2016                         18715.0
#
# ...

# %%
tables_list[0]
# Out:
#    Unnamed: 0  Year     Office    GOP    DFL Others
# 0           0  2018   Governor  42.4%  53.9%   3.7%
# 1           1  2018    Senator  36.2%  60.3%   3.4%
# 2           2  2018    Senator  42.4%  53.0%   4.6%
# 3           3  2016  President  44.9%  46.4%   8.6%
# 4           4  2014   Governor  44.5%  50.1%   5.4%

# %%
mf_list=tables_list[0]

# %%
ms_list=tables_list[2]

# %%
ms_list
# Out:
#    Unnamed: 0  Year  Nominal GDP(in bil. US-Dollar)  \
# 0           0  2020                         20234.0
# 1           1  2019                         21439.0
# 2           2  2018                         20580.2
# 3           3  2017                         19519.4
# 4           4  2016                         18715.0
#
#    GDP per capita(in US-Dollar)  GDP growth(real)  Inflation rate(in percent)  \
# 0                         57589              -5.9                        0.62
# 1                         64674               2.2                        1.80
# 2                         62869               3.0                        2.40
# 3                         60000               2.3                        2.10
# 4                         57878               1.7                        1.30
#
#    Unemployment (in percent)  Budget balance(in % of GDP)[107]  \
# 0                       11.1                               NaN
# ...

# %%
dates=['Mar 7,2011']

# %%
dates
# Out:
# ['Mar 7,2011']

# %%
pd.to_datetime(dates,dayfirst=False)
# Out:
# DatetimeIndex(['2011-03-07'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['2013-10-15','Jan 8,2022','234'],errors='ignore')
# Out:
# Index(['2013-10-15', 'Jan 8,2022', '234'], dtype='object')

# %%
pd.to_datetime(['2013-10-15','Jan 8,2022','234'],errors='coerce')
# Out:
# DatetimeIndex(['2013-10-15', '2022-01-08', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
epoch_time=112234
pd.to_datetime(epoch_time,unit='s')
# Out:
# Timestamp('1970-01-02 07:10:34')

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
orders.groupby('Order Priority').Sales.sum()
# Out:
# Order Priority
# Critical         2.724799e+06
# High             3.267356e+06
# Low              3.282630e+06
# Medium           2.862452e+06
# Not Specified    2.778363e+06
# Name: Sales, dtype: float64

# %%
orders.groupby('Order Priority').Sales.mean()
# Out:
# Order Priority
# Critical         1694.526538
# High             1848.052240
# Low              1908.506033
# Medium           1755.028890
# Not Specified    1661.700536
# Name: Sales, dtype: float64

# %%
orders.groupby('Order Priority').Sales.max()
# Out:
# Order Priority
# Critical         41343.21
# High             28664.52
# Low              29884.60
# Medium           89061.05
# Not Specified    33367.85
# Name: Sales, dtype: float64

# %%
orders.groupby('Order Priority').Sales.agg(['sum','mean','max','min'])
# Out:
#                          sum         mean       max   min
# Order Priority
# Critical        2.724799e+06  1694.526538  41343.21  2.24
# High            3.267356e+06  1848.052240  28664.52  3.41
# Low             3.282630e+06  1908.506033  29884.60  3.63
# Medium          2.862452e+06  1755.028890  89061.05  4.94
# Not Specified   2.778363e+06  1661.700536  33367.85  3.85

# %%
orders.groupby(['Order Priority','Ship Mode']).Sales.agg(['sum','mean','max','min'])
# Out:
#                                         sum         mean       max      min
# Order Priority Ship Mode
# Critical       Delivery Truck  1.204481e+06  5282.811596  26133.39   72.460
#                Express Air     2.322686e+05  1161.342835   7841.57   15.600
#                Regular Air     1.288049e+06  1091.567001  41343.21    2.240
# High           Delivery Truck  1.416794e+06  5712.880694  28389.14  102.900
#                Express Air     2.465870e+05  1163.146222  13064.06   24.160
#                Regular Air     1.603975e+06  1226.280543  28664.52    3.410
# Low            Delivery Truck  1.431122e+06  5724.489248  29345.27  131.270
#                Express Air     2.178006e+05  1146.318966  23949.51   10.170
#                Regular Air     1.633707e+06  1276.333954  29884.60    3.630
# Medium         Delivery Truck  1.042383e+06  5084.792888  25313.34  121.624
#                Express Air     2.804178e+05  1395.113393  24051.49   14.850
# ...

# %%
orders.groupby('Order Priority').mean()
# Out:
#                      Row ID      Order ID  Order Quantity        Sales  \
# Order Priority
# Critical        4174.217662  29779.445896       25.335821  1694.526538
# High            4280.267534  30541.058824       25.834276  1848.052240
# Low             4123.423837  29418.526163       25.797093  1908.506033
# Medium          4306.515635  30724.761496       25.361128  1755.028890
# Not Specified   4114.790072  29356.251794       25.494617  1661.700536
#
#                 Discount      Profit  Unit Price  Shipping Cost  \
# Order Priority
# Critical        0.049876  113.729373   87.825373      13.129776
# High            0.049446  230.243022   88.736985      12.819808
# Low             0.050366  224.526069   84.004401      13.341198
# Medium          0.050202  200.522195   91.369877      12.577517
# Not Specified   0.048481  130.732613   94.974402      12.315879
#
#                 Product Base Margin
# Order Priority
# Critical                   0.514201
# ...

# %%
sales.head(3)
# Out:
#    Row ID  Order ID Order Priority  Order Quantity    Sales  Discount  \
# 0       1         3            Low               6   261.54      0.04
# 1       2         6  Not Specified               2     6.93      0.01
# 3       4        32           High              24  1761.40      0.09
#
#         Ship Mode   Profit  Unit Price  Shipping Cost       Customer Name  \
# 0     Regular Air  -213.25       38.94          35.00  Muhammed MacIntyre
# 1     Regular Air    -4.64        2.08           2.56         Ruben Dartt
# 3  Delivery Truck -1748.56       70.89          89.30       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies
# 1  Alberta     West        Corporate  Office Supplies
# 3  Alberta     West        Corporate        Furniture
#
#             Product Sub-Category  \
# 0         Storage & Organization
# 1  Scissors, Rulers and Trimmers
# 3                         Tables
#
# ...

# %%
sales.duplicated()
# Out:
# 0       False
# 1       False
# 3       False
# 5       False
# 6       False
#         ...
# 8385    False
# 8386    False
# 8387    False
# 8388    False
# 8389    False
# Length: 8388, dtype: bool

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales['Customer Name'].duplicated().sum()
# Out:
# 7593

# %%
sales[sales['Customer Name'].duplicated(keep='last')].head(3)
# Out:
#    Row ID  Order ID Order Priority  Order Quantity    Sales  Discount  \
# 0       1         3            Low               6   261.54      0.04
# 1       2         6  Not Specified               2     6.93      0.01
# 3       4        32           High              24  1761.40      0.09
#
#         Ship Mode   Profit  Unit Price  Shipping Cost       Customer Name  \
# 0     Regular Air  -213.25       38.94          35.00  Muhammed MacIntyre
# 1     Regular Air    -4.64        2.08           2.56         Ruben Dartt
# 3  Delivery Truck -1748.56       70.89          89.30       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies
# 1  Alberta     West        Corporate  Office Supplies
# 3  Alberta     West        Corporate        Furniture
#
#             Product Sub-Category  \
# 0         Storage & Organization
# 1  Scissors, Rulers and Trimmers
# 3                         Tables
#
# ...

# %%
sales['Customer Name'].shape
# Out:
# (8388,)

# %%
sales['Customer Name'].drop_duplicates().shape
# Out:
# (795,)

# %%
ser1=pd.Series([0,34,45,33,32,4],index=list('pavuhl'))

# %%
ser2=pd.Series([3,5,23,34,6,65],index=list('PAVANA'))

# %%
ser1+ser2
# Out:
# A   NaN
# A   NaN
# A   NaN
# N   NaN
# P   NaN
# V   NaN
# a   NaN
# h   NaN
# l   NaN
# p   NaN
# u   NaN
# v   NaN
# dtype: float64

# %%
ser2=pd.Series([3,5,23,34,6,65],index=list('pavunl'))

# %%
ser1+ser2
# Out:
# a    39.0
# h     NaN
# l    69.0
# n     NaN
# p     3.0
# u    67.0
# v    68.0
# dtype: float64

# %%
import numpy as np
df1=pd.DataFrame(np.arange(4).reshape(2,2),columns=list('AG'))

# %%
df1
# Out:
#    A  G
# 0  0  1
# 1  2  3

# %%
df2=pd.DataFrame(np.arange(9).reshape(3,3),columns=list('ABC'),index=['prod1','prod2','prod3'])

# %%
df2
# Out:
#        A  B  C
# prod1  0  1  2
# prod2  3  4  5
# prod3  6  7  8

# %%
df1+df2
# Out:
#         A   B   C   G
# 0     NaN NaN NaN NaN
# 1     NaN NaN NaN NaN
# prod1 NaN NaN NaN NaN
# prod2 NaN NaN NaN NaN
# prod3 NaN NaN NaN NaN

# %%
df1.add(df2,fill_value=0)
# Out:
#          A    B    C    G
# 0      0.0  NaN  NaN  1.0
# 1      2.0  NaN  NaN  3.0
# prod1  0.0  1.0  2.0  NaN
# prod2  3.0  4.0  5.0  NaN
# prod3  6.0  7.0  8.0  NaN

# %%
pd.describe_option()
# Out:
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# compute.use_numba : bool
#     Use the numba engine option for select operations if it is installed,
#     the default is False
#     Valid values: False,True
#     [default: False] [currently: False]
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller then the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# ...

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
pd.set_option('display.max_rows',None)

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.250       38.94  ...  Muhammed MacIntyre
# 1      0.01     Regular Air    -4.640        2.08  ...         Ruben Dartt
# 2      0.07     Regular Air  1054.820      107.53  ...       Liz Pelletier
# 3      0.09  Delivery Truck -1748.560       70.89  ...       Liz Pelletier
# 4      0.04     Regular Air   -85.129        7.99  ...       Liz Pelletier
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
pd.reset_option('display.max_rows')

# %%
orders
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1          2         6 2012-02-20  Not Specified               2      6.9300
# 2          3        32 2011-07-15           High              26   2808.0800
# 3          4        32 2011-07-15           High              24   1761.4000
# 4          5        32 2011-07-15           High              23    160.2335
# ...      ...       ...        ...            ...             ...         ...
# 8394    8395     59971 2011-05-31       Critical              26    437.7700
# 8395    8396     59971 2011-05-31       Critical              45    514.8600
# 8396    8397     59971 2011-05-31       Critical              12    356.2700
# 8397    8398     59973 2011-11-15            Low              29  11039.7500
# 8398    8399     59973 2011-11-15            Low              30   4982.9440
#
# ...

# %%
orders.rank().head()
# Out:
#    Row ID  Order ID  Order Date  Order Priority  Order Quantity   Sales  \
# 0     1.0       1.0      3801.5          4236.5           954.5  3261.0
# 1     2.0       2.0      6588.0          7563.5           241.5    24.0
# 2     3.0       4.5      5376.0          2492.5          4261.5  6981.0
# 3     4.0       4.5      5376.0          2492.5          3911.5  6349.0
# 4     5.0       4.5      5376.0          2492.5          3719.5  2299.0
#
#    Discount  Ship Mode  Profit  Unit Price  Shipping Cost  Customer Name  \
# 0    3491.5     5264.5  1009.0      5098.0         7512.0         5854.0
# 1    1159.5     5264.5  4038.5       200.5         1815.5         7005.5
# 2    5751.5     5264.5  7754.0      6588.5         3958.5         4982.0
# 3    7260.5      573.5    88.0      6072.0         8364.0         4982.0
# 4    3491.5     5264.5  2069.0      2578.0         3200.0         4982.0
#
#    Province  Region  Customer Segment  Product Category  Product Sub-Category  \
# ...

# %%
orders['Rank_by_profit']=orders['Profit'].rank(ascending=True)

# %%
orders.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity      Sales  \
# 0       1         3 2010-10-13            Low               6   261.5400
# 1       2         6 2012-02-20  Not Specified               2     6.9300
# 2       3        32 2011-07-15           High              26  2808.0800
# 3       4        32 2011-07-15           High              24  1761.4000
# 4       5        32 2011-07-15           High              23   160.2335
#
#    Discount       Ship Mode    Profit  Unit Price  Shipping Cost  \
# 0      0.04     Regular Air  -213.250       38.94          35.00
# 1      0.01     Regular Air    -4.640        2.08           2.56
# 2      0.07     Regular Air  1054.820      107.53           5.81
# 3      0.09  Delivery Truck -1748.560       70.89          89.30
# 4      0.04     Regular Air   -85.129        7.99           5.03
#
#         Customer Name Province   Region Customer Segment Product Category  \
# ...

# %%
orders.sort_values('Profit',ascending=False).head()
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 4189    4190     29766 2009-03-21         Medium              13  89061.05
# 1315    1316      9637 2009-01-03            Low              49  28359.40
# 2908    2909     20967 2011-03-15           High              50  28664.52
# 4628    4629     32932 2010-01-09            Low              49  29884.60
# 4095    4096     29187 2009-07-31            Low              35  26095.13
#
#       Discount       Ship Mode    Profit  Unit Price  Shipping Cost  \
# 4189      0.00     Regular Air  27220.69     6783.02          24.49
# 1315      0.05     Regular Air  14440.39      574.74          24.49
# 2908      0.09     Regular Air  13340.26      599.99          24.49
# 4628      0.05     Regular Air  12748.86      599.99          24.49
# 4095      0.03  Delivery Truck  12606.81      808.49          55.30
#
#           Customer Name          Province    Region Customer Segment  \
# ...

# %%
orders.isnull().sum()
# Out:
# Row ID                   0
# Order ID                 0
# Order Date               0
# Order Priority           0
# Order Quantity           0
# Sales                    0
# Discount                 0
# Ship Mode                0
# Profit                   0
# Unit Price               0
# Shipping Cost            0
# Customer Name            0
# Province                 0
# Region                   0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Name             0
# Product Container        0
# Product Base Margin     63
# Ship Date                0
# Rank_by_profit           0
# dtype: int64

# %%
orders[orders['Product Base Margin'].isnull()]
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 23        24       134 2012-04-30  Not Specified              11   1132.60
# 97        98       613 2011-06-17           High              22    905.08
# 102      103       643 2011-03-24           High              21   2781.82
# 260      261      1824 2009-05-04       Critical              39  10656.26
# 279      280      1925 2012-03-04       Critical               7   1874.37
# ...      ...       ...        ...            ...             ...       ...
# 7628    7629     54592 2011-06-12            Low              28   1971.56
# 7699    7700     55202 2011-08-24            Low              33   3093.76
# 7769    7770     55621 2011-03-15            Low              50   6356.68
# 7825    7826     55938 2012-07-02  Not Specified              18   1769.90
# 8357    8358     59714 2010-12-13       Critical              26   9225.65
#
# ...

# %%
orders.notnull().shape
# Out:
# (8399, 22)

# %%
orders.dropna(how='any').shape
# Out:
# (8336, 22)

# %%
orders.dropna(how='all').shape
# Out:
# (8399, 22)

# %%
orders.dropna(subset=['Customer Name','Province'],how='all').shape
# Out:
# (8399, 22)

# %%
orders.dropna(thresh=1).shape
# Out:
# (8399, 22)

# %%
dfp=pd.pivot_table(orders,'Sales',index=['Order Priority'],columns=['Ship Mode'],aggfunc=np.mean,margins=True)

# %%
dfp
# Out:
# Ship Mode       Delivery Truck  Express Air  Regular Air          All
# Order Priority
# Critical           5282.811596  1161.342835  1091.567001  1694.526538
# High               5712.880694  1163.146222  1226.280543  1848.052240
# Low                5724.489248  1146.318966  1276.333954  1908.506033
# Medium             5084.792888  1395.113393  1256.858600  1755.028890
# Not Specified      5256.271665  1151.916308  1128.363314  1661.700536
# All                5431.831342  1204.902235  1197.177545  1775.878179

# %%
orders.dtypes
# Out:
# Row ID                           int64
# Order ID                         int64
# Order Date              datetime64[ns]
# Order Priority                  object
# Order Quantity                   int64
# Sales                          float64
# Discount                       float64
# Ship Mode                       object
# Profit                         float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer Name                   object
# Province                        object
# Region                          object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Name                    object
# Product Container               object
# Product Base Margin            float64
# Ship Date               datetime64[ns]
# Rank_by_profit                 float64
# dtype: object

# %%
import datetime
from datetime import datetime as dt
orders['Ship Date'].dt.weekofyear.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8784\1699625946.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   orders['Ship Date'].dt.weekofyear.head()
# 0    42
# 1     8
# 2    28
# 3    28
# 4    28
# Name: Ship Date, dtype: int64

# %%
orders['Ship Date'].dt.dayofweek.head()
# Out:
# 0    2
# 1    1
# 2    6
# 3    5
# 4    6
# Name: Ship Date, dtype: int64

# %%
orders.year=orders['Ship Date'].dt.year.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8784\17816735.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   orders.year=orders['Ship Date'].dt.year.head()

# %%
orders.year
# Out:
# 0    2010
# 1    2012
# 2    2011
# 3    2011
# 4    2011
# Name: Ship Date, dtype: int64

# %%
orders['Ship Date'].dt.month.head()
# Out:
# 0    10
# 1     2
# 2     7
# 3     7
# 4     7
# Name: Ship Date, dtype: int64

# %%
orders['Order Priority'].unique()
# Out:
# array(['Low', 'Not Specified', 'High', 'Critical', 'Medium'], dtype=object)

# %%
orders['Order Priority'].nunique()
# Out:
# 5

# %%
orders['Order Priority'].str.capitalize()
# Out:
# 0                 Low
# 1       Not specified
# 2                High
# 3                High
# 4                High
#             ...
# 8394         Critical
# 8395         Critical
# 8396         Critical
# 8397              Low
# 8398              Low
# Name: Order Priority, Length: 8399, dtype: object

# %%
orders['Order Priority len']=orders['Order Priority'].str.len().head()

# %%
orders['Order Priority len']
# Out:
# 0        3.0
# 1       13.0
# 2        4.0
# 3        4.0
# 4        4.0
#         ...
# 8394     NaN
# 8395     NaN
# 8396     NaN
# 8397     NaN
# 8398     NaN
# Name: Order Priority len, Length: 8399, dtype: float64

# %%
orders['Order Priority'].str.isupper().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Order Priority, dtype: bool

# %%
orders['Order Priority'].str.replace('Not Specified','Nan')
# Out:
# 0            Low
# 1            Nan
# 2           High
# 3           High
# 4           High
#           ...
# 8394    Critical
# 8395    Critical
# 8396    Critical
# 8397         Low
# 8398         Low
# Name: Order Priority, Length: 8399, dtype: object

# %%
orders['Order Priority'].str.contains('Not Specified')
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# Name: Order Priority, Length: 8399, dtype: bool

# %% [markdown]
# # scatter plot matrix

# %%
import matplotlib
# %matplotlib inline

# %%
pd.plotting.scatter_matrix(orders.loc[:,'Sales':'Shipping Cost'],figsize=(12,8),diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='Sales', ylabel='Sales'>,
#         <AxesSubplot:xlabel='Discount', ylabel='Sales'>,
#         <AxesSubplot:xlabel='Profit', ylabel='Sales'>,
#         <AxesSubplot:xlabel='Unit Price', ylabel='Sales'>,
#         <AxesSubplot:xlabel='Shipping Cost', ylabel='Sales'>],
#        [<AxesSubplot:xlabel='Sales', ylabel='Discount'>,
#         <AxesSubplot:xlabel='Discount', ylabel='Discount'>,
#         <AxesSubplot:xlabel='Profit', ylabel='Discount'>,
#         <AxesSubplot:xlabel='Unit Price', ylabel='Discount'>,
#         <AxesSubplot:xlabel='Shipping Cost', ylabel='Discount'>],
#        [<AxesSubplot:xlabel='Sales', ylabel='Profit'>,
#         <AxesSubplot:xlabel='Discount', ylabel='Profit'>,
#         <AxesSubplot:xlabel='Profit', ylabel='Profit'>,
#         <AxesSubplot:xlabel='Unit Price', ylabel='Profit'>,
#         <AxesSubplot:xlabel='Shipping Cost', ylabel='Profit'>],
#        [<AxesSubplot:xlabel='Sales', ylabel='Unit Price'>,
# ...

# %%
import seaborn as sns
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
for key,value in iris.iteritems():
    print(key,value[0]*5)
# Out:
# sepal_length 25.5
# sepal_width 17.5
# petal_length 7.0
# petal_width 1.0
# species setosasetosasetosasetosasetosa

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.columns=[x.replace('_','.') for x in iris.columns]

# %%
iris.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'species'],
#       dtype='object')

# %%
iris.columns=[x.lower() for x in iris.columns]

# %%
iris.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'species'],
#       dtype='object')

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris_data_list=['setosa','versicolor']
iris_sv=iris[iris.species.isin(iris_data_list)]

# %%
iris_sv
# Out:
#     sepal.length  sepal.width  petal.length  petal.width     species
# 0            5.1          3.5           1.4          0.2      setosa
# 1            4.9          3.0           1.4          0.2      setosa
# 2            4.7          3.2           1.3          0.2      setosa
# 3            4.6          3.1           1.5          0.2      setosa
# 4            5.0          3.6           1.4          0.2      setosa
# ..           ...          ...           ...          ...         ...
# 95           5.7          3.0           4.2          1.2  versicolor
# 96           5.7          2.9           4.2          1.3  versicolor
# 97           6.2          2.9           4.3          1.3  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 99           5.7          2.8           4.1          1.3  versicolor
#
# [100 rows x 5 columns]

# %%
iris_sv.species.unique()
# Out:
# array(['setosa', 'versicolor'], dtype=object)

# %% [markdown]
# # 2 nd day

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\HP\Desktop\survey_results_public.csv')

# %%
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
pd.set_option('display.max_columns',154)
pd.set_option('display.max_rows',154)
df.columns
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', length=154)

# %%
df.shape
# Out:
# (51392, 154)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51392 entries, 0 to 51391
# Columns: 154 entries, Respondent to ExpectedSalary
# dtypes: float64(6), int64(1), object(147)
# memory usage: 60.4+ MB

# %%
df1=pd.read_csv(r'C:\Users\HP\Downloads\survey_results_schema.csv')

# %%
df1.head()
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...
# 3       Country            In which country do you currently live?
# 4    University  Are you currently enrolled in a formal, degree...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column    154 non-null    object
#  1   Question  154 non-null    object
# dtypes: object(2)
# memory usage: 2.5+ KB

# %%
df1.iloc[0]
# Out:
# Column                Respondent
# Question    Respondent ID number
# Name: 0, dtype: object

# %%
df1.iloc[0:5,0]
# Out:
# 0      Respondent
# 1    Professional
# 2    ProgramHobby
# 3         Country
# 4      University
# Name: Column, dtype: object

# %%
df1.iloc[0:5,[0,1]]
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...
# 3       Country            In which country do you currently live?
# 4    University  Are you currently enrolled in a formal, degree...

# %%
df1.iloc[[0,1,2],[0,1]]
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...

# %%
df1.shape
# Out:
# (154, 2)

# %%
list_columns=df.columns.values.tolist()

# %%
list_columns
# Out:
# ['Respondent',
#  'Professional',
#  'ProgramHobby',
#  'Country',
#  'University',
#  'EmploymentStatus',
#  'FormalEducation',
#  'MajorUndergrad',
#  'HomeRemote',
#  'CompanySize',
#  'CompanyType',
#  'YearsProgram',
#  'YearsCodedJob',
#  'YearsCodedJobPast',
#  'DeveloperType',
#  'WebDeveloperType',
#  'MobileDeveloperType',
#  'NonDeveloperType',
#  'CareerSatisfaction',
#  'JobSatisfaction',
#  'ExCoderReturn',
#  'ExCoderNotForMe',
#  'ExCoderBalance',
#  'ExCoder10Years',
#  'ExCoderBelonged',
#  'ExCoderSkills',
#  'ExCoderWillNotCode',
#  'ExCoderActive',
#  'PronounceGIF',
#  'ProblemSolving',
#  'BuildingThings',
#  'LearningNewTech',
#  'BoringDetails',
#  'JobSecurity',
#  'DiversityImportant',
#  'AnnoyingUI',
#  'FriendsDevelopers',
#  'RightWrongWay',
#  'UnderstandComputers',
#  'SeriousWork',
#  'InvestTimeTools',
#  'WorkPayCare',
#  'KinshipDevelopers',
#  'ChallengeMyself',
#  'CompetePeers',
#  'ChangeWorld',
#  'JobSeekingStatus',
#  'HoursPerWeek',
# ...

# %%
'Hobbyist'  in list_columns
# Out:
# False

# %%
df.set_index('Country',inplace=True)

# %%
df.index.astype('str')
# Out:
# Index(['United States', 'United Kingdom', 'United Kingdom', 'United States',
#        'Switzerland', 'New Zealand', 'United States', 'Poland', 'Colombia',
#        'France',
#        ...
#        'France', 'Sweden', 'United States', 'United Kingdom', 'Romania',
#        'United States', 'Venezuela', 'Canada', 'United States', 'Ireland'],
#       dtype='object', name='Country', length=51392)

# %%
df.loc['United States']
# Out:
#                Respondent                                       Professional  \
# Country
# United States           1                                            Student
# United States           4  Professional non-developer who sometimes write...
# United States           7  Professional non-developer who sometimes write...
# United States          11  Professional non-developer who sometimes write...
# United States          16                             Professional developer
# ...                   ...                                                ...
# United States       51381                             Professional developer
# United States       51382  Professional non-developer who sometimes write...
# United States       51385                             Professional developer
# United States       51388                             Professional developer
# United States       51391                             Professional developer
#
# ...

# %%
df.loc['Canada']
# Out:
#          Respondent                                       Professional  \
# Country
# Canada           12                             Professional developer
# Canada           61  Professional non-developer who sometimes write...
# Canada          188                             Professional developer
# Canada          189                                            Student
# Canada          193                             Professional developer
# ...             ...                                                ...
# Canada        51185                             Professional developer
# Canada        51192                             Professional developer
# Canada        51199                                            Student
# Canada        51207                             Professional developer
# Canada        51390                             Professional developer
#
#                                       ProgramHobby      University  \
# Country
# ...

# %%
df1.set_index('Column',inplace=True)

# %%
df1.index
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', name='Column', length=154)

# %%
type(df1.index)
# Out:
# pandas.core.indexes.base.Index

# %%
df1.index.astype('str')
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', name='Column', length=154)

# %%
df1.index.value_counts()
# Out:
# Respondent                          1
# InTheZone                           1
# Methodology                         1
# VersionControl                      1
# CheckInCode                         1
# ShipIt                              1
# OtherPeoplesCode                    1
# ProjectManagement                   1
# EnjoyDebugging                      1
# DifficultCommunication              1
# InfluenceWorkstation                1
# CollaborateRemote                   1
# MetricAssess                        1
# EquipmentSatisfiedMonitors          1
# EquipmentSatisfiedCPU               1
# EquipmentSatisfiedRAM               1
# EquipmentSatisfiedStorage           1
# EquipmentSatisfiedRW                1
# AuditoryEnvironment                 1
# IDE                                 1
# WantWorkPlatform                    1
# HaveWorkedPlatform                  1
# Currency                            1
# Overpaid                            1
# TabsSpaces                          1
# ...

# %%
df.sort_index(inplace=True)

# %%
df.index
# Out:
# Index(['Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan',
#        ...
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe'],
#       dtype='object', name='Country', length=51392)

# %%
filt=(df.index=='Canada')
df.loc[filt,['EmploymentStatus']]
# Out:
#                            EmploymentStatus
# Country
# Canada                   Employed full-time
# Canada                   Employed part-time
# Canada                   Employed full-time
# Canada                   Employed full-time
# Canada                   Employed full-time
# ...                                     ...
# Canada                   Employed full-time
# Canada   Not employed, but looking for work
# Canada                   Employed full-time
# Canada                   Employed full-time
# Canada                   Employed part-time
#
# [2233 rows x 1 columns]

# %%
highsalary=(df['Salary']>70000)
df.loc[highsalary,['Respondent']]
# Out:
#                       Respondent
# Country
# Afghanistan                51257
# Albania                     4311
# Albania                    26854
# Anguilla                   32648
# Argentina                  50858
# ...                          ...
# United States              36560
# United States              36545
# Uruguay                      225
# Venezuela                  18021
# Virgin Islands (USA)       41711
#
# [3942 rows x 1 columns]

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df.columns
# Out:
# Index(['RESPONDENT', 'PROFESSIONAL', 'PROGRAMHOBBY', 'UNIVERSITY',
#        'EMPLOYMENTSTATUS', 'FORMALEDUCATION', 'MAJORUNDERGRAD', 'HOMEREMOTE',
#        'COMPANYSIZE', 'COMPANYTYPE',
#        ...
#        'STACKOVERFLOWMAKEMONEY', 'GENDER', 'HIGHESTEDUCATIONPARENTS', 'RACE',
#        'SURVEYLONG', 'QUESTIONSINTERESTING', 'QUESTIONSCONFUSING',
#        'INTERESTEDANSWERS', 'SALARY', 'EXPECTEDSALARY'],
#       dtype='object', length=153)

# %%
df.rename(columns={'RESPONDENT':'respondent'},inplace=True)

# %%
df.columns
# Out:
# Index(['respondent', 'PROFESSIONAL', 'PROGRAMHOBBY', 'UNIVERSITY',
#        'EMPLOYMENTSTATUS', 'FORMALEDUCATION', 'MAJORUNDERGRAD', 'HOMEREMOTE',
#        'COMPANYSIZE', 'COMPANYTYPE',
#        ...
#        'STACKOVERFLOWMAKEMONEY', 'GENDER', 'HIGHESTEDUCATIONPARENTS', 'RACE',
#        'SURVEYLONG', 'QUESTIONSINTERESTING', 'QUESTIONSCONFUSING',
#        'INTERESTEDANSWERS', 'SALARY', 'EXPECTEDSALARY'],
#       dtype='object', length=153)

# %%
df.loc[2,3]='pavan'### adding new rows

# %%
df.loc[2]
# Out:
# respondent              hI
# PROFESSIONAL           NaN
# PROGRAMHOBBY           NaN
# UNIVERSITY             NaN
# EMPLOYMENTSTATUS       NaN
#                      ...
# INTERESTEDANSWERS      NaN
# SALARY                 NaN
# EXPECTEDSALARY         NaN
# 3                    pavan
# renspondent            NaN
# Name: 2, Length: 155, dtype: object

# %%
df.loc[2,3]
# Out:
# 'pavan'

# %%
df.loc['Afghanistan','respondent']='bye'###updating rows

# %%
df.loc['Canada']
# Out:
#          respondent                                       PROFESSIONAL  \
# Country
# Canada       1174.0                             Professional developer
# Canada       7249.0                             Professional developer
# Canada      30577.0                             Professional developer
# Canada      34425.0                             Professional developer
# Canada      43545.0                             Professional developer
# ...             ...                                                ...
# Canada      16363.0                             Professional developer
# Canada       7956.0  Professional non-developer who sometimes write...
# Canada       2526.0                             Professional developer
# Canada        397.0                             Professional developer
# Canada       2680.0                             Professional developer
#
#                       PROGRAMHOBBY      UNIVERSITY  \
# Country
# ...

# %%
df.head()
# Out:
#             respondent            PROFESSIONAL               PROGRAMHOBBY  \
# Country
# Afghanistan        bye  Professional developer                         No
# Afghanistan        bye  Professional developer                  Yes, both
# Afghanistan        bye                 Student  Yes, I program as a hobby
# Afghanistan        bye  Professional developer  Yes, I program as a hobby
# Afghanistan        bye  Professional developer  Yes, I program as a hobby
#
#                       UNIVERSITY                        EMPLOYMENTSTATUS  \
# Country
# Afghanistan                   No                      Employed full-time
# Afghanistan                   No  Not employed, and not looking for work
# Afghanistan       Yes, full-time                      Employed full-time
# Afghanistan  I prefer not to say                      Employed full-time
# Afghanistan                   No                      Employed full-time
#
# ...

# %%
dataf={
    'A':[4,5,6],
    'B':[5,6,7],
    'C':[7,8,9]}
    
data=pd.DataFrame(dataf)
print(data)
# Out:
#    A  B  C
# 0  4  5  7
# 1  5  6  8
# 2  6  7  9

# %%
 def square_fun(x):
        return x**2

# %%
data=data.applymap(lambda x:x**2)

# %%
data
# Out:
#     A   B   C
# 0  16  25  49
# 1  25  36  64
# 2  36  49  81

# %%
data['D']=data.apply(lambda row:row.sum(),axis=1)

# %%
data
# Out:
#     A   B   C    D
# 0  16  25  49   90
# 1  25  36  64  125
# 2  36  49  81  166

# %%
data['A'].map({16:61,36:63})
# Out:
# 0    61.0
# 1     NaN
# 2    63.0
# Name: A, dtype: float64

# %%
data
# Out:
#     A   B   C    D
# 0  16  25  49   90
# 1  25  36  64  125
# 2  36  49  81  166
